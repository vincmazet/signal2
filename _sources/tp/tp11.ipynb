# %% [markdown]
# # ✎ Représentation d'un signal

# %% [markdown]
# Cet exercice est fortement fondé sur le code de la section
# [Écrire un programme Python](https://vincmazet.github.io/signal2/python.html#ecrire-un-programme-python).
#
# Par convention, les modules sont importés en début de notebook. Ils sont également renommé (`numpy` en `np` par exemple) pour raccourcir le code lorsqu'il seront utilisés.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Les valeurs des paramètres sont à mettre à jour en fonction des données de l'énoncé.

# %%
A = 2
a = 0.5
phi = 1
f = 2

# %% [markdown]
# Le pas de temps est choisi par essai-erreur pour obtenir une jolie courbe.

# %%
t = np.arange(0, 10, 0.02)

# %% [markdown]
# Le signal est une sinusoïde amortie.
# J'utilise deux variables intermédiaires pour la créer.

# %%
# Sinusoïde
sinus = np.sin(2*np.pi*f*t + phi)

# Exponentielle décroissante
expo = np.exp(-a*t)

# Le signal est égal à A × sinus × expo
x = A*sinus*expo

# %% [markdown]
# Affichage !

# %%
plt.figure()
plt.plot(t,x)
plt.xlabel("$t$")
plt.ylabel("$x(t)$")
plt.title("Sinusoïde amortie")
plt.show()

# %% [markdown]
# Si vous avez des difficultés pour reproduire ces résultats ou pour tout complément, [envoyez-moi un mail](mailto:vincent.mazet@unistra.fr) !
