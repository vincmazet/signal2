# %% [markdown]
# # Schéma de la transformation bilinéaire

# %%
import numpy as np
import blocks as blk

# %%
fig, ax = blk.drawing(8.6, 3.1, debug=False)

blk.block(ax, 0, 2.1, 3.5, 1, "Gabarit numérique")
blk.arrow(ax, 3.5, 2.6, 1.5, 0)
blk.block(ax, 5, 2.1, 3.5, 1, "Gabarit analogique")
blk.arrow(ax, 6.75, 2.1, 0, -1)
blk.block(ax, 5, 0.1, 3.5, 1, "Filtre analogique")
blk.arrow(ax, 5, 0.6, -1.5, 0)
blk.block(ax, 0, 0.1, 3.5, 1, "Filtre numérique")

blk.saving(ax, "schema-tansf-bilineaire.svg")
blk.saving(ax, "schema-tansf-bilineaire.png")
