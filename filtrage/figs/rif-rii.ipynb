# %% [markdown]
# # Schémas-blocs des RIF et RII

# %%
import numpy as np
import blocks as blk

# %%
fig, ax = blk.drawing(9, 7.7, debug=False)

ox, oy = 1, .4

# Retard
blk.block(ax, 3-ox, 6-oy, 1, 1, "$z^{-1}$")
blk.block(ax, 3-ox, 4-oy, 1, 1, "$z^{-1}$")
blk.block(ax, 3-ox, 1.5-oy, 1, 1, "$z^{-1}$")

# Coefficients
blk.block(ax, 5-ox, 7-oy, 1, 1, "$b_0$")
blk.block(ax, 5-ox, 5-oy, 1, 1, "$b_1$")
blk.block(ax, 5-ox, 3-oy, 1, 1, "$b_2$")
blk.block(ax, 5-ox, .5-oy, 1, 1, "$b_N$")

# Sommateurs
blk.add(ax, 7.5-ox, 7.5-oy)
blk.add(ax, 7.5-ox, 5.5-oy)
blk.add(ax, 7.5-ox, 3.5-oy)

# Flèches horizontales (gauche)
blk.arrow(ax, 2.0-ox, 7.5-oy, 3, 0)
blk.arrow(ax, 3.5-ox, 5.5-oy, 1.5, 0)
blk.arrow(ax, 3.5-ox, 3.5-oy, 1.5, 0)
blk.arrow(ax, 3.5-ox, 1.0-oy, 1.5, 0)

# Flèches verticales (gauche)
blk.arrow(ax, 3.5-ox, 7.5-oy, 0, -.5)
blk.arrow(ax, 3.5-ox, 6.0-oy, 0, -1)
blk.line( ax, 3.5-ox, 4.0-oy, 0, -0.9)
blk.arrow(ax, 3.5-ox, 2.8-oy, 0, -.3)
blk.line( ax, 3.5-ox, 1.5-oy, 0, -.5)

# Flèches horizontales (droite)
blk.arrow(ax, 8-ox, 7.5-oy, 1, 0)
blk.arrow(ax, 6-ox, 7.5-oy, 1, 0)
blk.arrow(ax, 6-ox, 5.5-oy, 1, 0)
blk.arrow(ax, 6-ox, 3.5-oy, 1, 0)
blk.line( ax, 6-ox, 1.0-oy, 1.5, 0)

# Flèches verticales (droite)
blk.arrow(ax, 7.5-ox, 6.0-oy, 0, 1)
blk.arrow(ax, 7.5-ox, 4.0-oy, 0, 1)
blk.arrow(ax, 7.5-ox, 2.8-oy, 0, .2)
blk.line( ax, 7.5-ox, 1.0-oy, 0, 1.5)

# Etiquettes
blk.label(ax, 1.5-ox, 7.5-oy, "$x[n]$")
blk.label(ax, 9.5-ox, 7.5-oy, "$y[n]$")

# Suspensions
blk.line( ax, 3.5-ox, 2.9-oy, 0, .1)
blk.line( ax, 7.5-ox, 2.6-oy, 0, .1)

blk.saving(ax, "filtre-rif.svg")
blk.saving(ax, "filtre-rif.png")

# %%
fig, ax = blk.drawing(16, 8.8, debug=False)

# RIF ================================================================================

ox, oy = 1, -.5

# Retard
blk.block(ax, 3-ox, 6-oy, 1, 1, "$z^{-1}$")
blk.block(ax, 3-ox, 4-oy, 1, 1, "$z^{-1}$")
blk.block(ax, 3-ox, 1.5-oy, 1, 1, "$z^{-1}$")

# Coefficients
blk.block(ax, 5-ox, 7-oy, 1, 1, "$b_0$")
blk.block(ax, 5-ox, 5-oy, 1, 1, "$b_1$")
blk.block(ax, 5-ox, 3-oy, 1, 1, "$b_2$")
blk.block(ax, 5-ox, .5-oy, 1, 1, "$b_M$")

# Sommateurs
blk.add(ax, 7.5-ox, 7.5-oy)
blk.add(ax, 7.5-ox, 5.5-oy)
blk.add(ax, 7.5-ox, 3.5-oy)

# Flèches horizontales (gauche)
blk.arrow(ax, 2.0-ox, 7.5-oy, 3, 0)
blk.arrow(ax, 3.5-ox, 5.5-oy, 1.5, 0)
blk.arrow(ax, 3.5-ox, 3.5-oy, 1.5, 0)
blk.arrow(ax, 3.5-ox, 1.0-oy, 1.5, 0)

# Flèches verticales (gauche)
blk.arrow(ax, 3.5-ox, 7.5-oy, 0, -.5)
blk.arrow(ax, 3.5-ox, 6.0-oy, 0, -1)
blk.line( ax, 3.5-ox, 4.0-oy, 0, -0.9)
blk.arrow(ax, 3.5-ox, 2.8-oy, 0, -.3)
blk.line( ax, 3.5-ox, 1.5-oy, 0, -.5)

# Flèches horizontales (droite)
blk.arrow(ax, 6-ox, 7.5-oy, 1, 0)
blk.arrow(ax, 6-ox, 5.5-oy, 1, 0)
blk.arrow(ax, 6-ox, 3.5-oy, 1, 0)
blk.line( ax, 6-ox, 1.0-oy, 1.5, 0)

# Flèches verticales (droite)
blk.arrow(ax, 7.5-ox, 6.0-oy, 0, 1)
blk.arrow(ax, 7.5-ox, 4.0-oy, 0, 1)
blk.arrow(ax, 7.5-ox, 2.8-oy, 0, .2)
blk.line( ax, 7.5-ox, 1.0-oy, 0, 1.5)

# Etiquettes
blk.label(ax,  1.5-ox, 7.5-oy, "$x[n]$")
blk.label(ax,  5.5-ox, 0-oy, "Partie non récursive")

# Suspensions
blk.line( ax, 3.5-ox, 2.9-oy, 0, .1)
blk.line( ax, 7.5-ox, 2.6-oy, 0, .1)

# Milieu =============================================================================

blk.arrow(ax, 8-ox, 7.5-oy, 2, 0)
blk.label(ax, 9-ox, 8-oy, "$w[n]$")

# RII ================================================================================

ox = -6

# Retard
blk.block(ax, 7-ox, 6-oy, 1, 1, "$z^{-1}$")
blk.block(ax, 7-ox, 4-oy, 1, 1, "$z^{-1}$")
blk.block(ax, 7-ox, 1.5-oy, 1, 1, "$z^{-1}$")

# Coefficients
blk.block(ax, 5-ox, 7-oy, 1, 1, "$1/a_0$")
blk.block(ax, 5-ox, 5-oy, 1, 1, "$-a_1$")
blk.block(ax, 5-ox, 3-oy, 1, 1, "$-a_2$")
blk.block(ax, 5-ox, .5-oy, 1, 1, "$-a_N$")

# Sommateurs
blk.add(ax, 3.5-ox, 7.5-oy)
blk.add(ax, 3.5-ox, 5.5-oy)
blk.add(ax, 3.5-ox, 3.5-oy)

# Flèches horizontales (gauche)
# blk.arrow(ax, 8-ox, 7.5-oy, 1, 0)
blk.arrow(ax, 4-ox, 7.5-oy, 1, 0)
blk.arrow(ax, 5-ox, 5.5-oy, -1, 0)
blk.arrow(ax, 5-ox, 3.5-oy, -1, 0)
blk.line( ax, 5-ox, 1.0-oy, -1.5, 0)

# Flèches verticales (gauche)
blk.arrow(ax, 3.5-ox, 6.0-oy, 0, 1)
blk.arrow(ax, 3.5-ox, 4.0-oy, 0, 1)
blk.arrow(ax, 3.5-ox, 2.8-oy, 0, .2)
blk.line( ax, 3.5-ox, 1.0-oy, 0, 1.5)

# Flèches horizontales (droite)
blk.arrow(ax, 6.0-ox, 7.5-oy, 3, 0)
blk.arrow(ax, 7.5-ox, 5.5-oy, -1.5, 0)
blk.arrow(ax, 7.5-ox, 3.5-oy, -1.5, 0)
blk.arrow(ax, 7.5-ox, 1.0-oy, -1.5, 0)

# # Flèches verticales (droite)
blk.arrow(ax, 7.5-ox, 7.5-oy, 0, -.5)
blk.arrow(ax, 7.5-ox, 6.0-oy, 0, -1)
blk.line( ax, 7.5-ox, 4.0-oy, 0, -0.9)
blk.arrow(ax, 7.5-ox, 2.8-oy, 0, -.3)
blk.line( ax, 7.5-ox, 1.5-oy, 0, -.5)

# Etiquettes
blk.label(ax,  5.5-ox, 0-oy, "Partie récursive")
blk.label(ax,  9.5-ox, 7.5-oy, "$y[n]$")

# Suspensions
blk.line( ax, 7.5-ox, 2.9-oy, 0, .1)
blk.line( ax, 3.5-ox, 2.6-oy, 0, .1)

# ====================================================================================

blk.saving(ax, "filtre-rii.svg")
blk.saving(ax, "filtre-rii.png")
